# %% [markdown]
# # Assignment 3 - Pandas Data Analysis Practice
#
# *This assignment is a part of the course ["Data Analysis with Python: Zero to Pandas"](https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas)*
#
# In this assignment, you'll get to practice some of the concepts and skills covered this tutorial: https://jovian.ml/aakashns/python-pandas-data-analysis
#
# As you go through this notebook, you will find a **???** in certain places. To complete this assignment, you must replace all the **???** with appropriate values, expressions or statements to ensure that the notebook runs properly end-to-end.
#
# Some things to keep in mind:
#
# * Make sure to run all the code cells, otherwise you may get errors like `NameError` for undefined variables.
# * Do not change variable names, delete cells or disturb other existing code. It may cause problems during evaluation.
# * In some cases, you may need to add some code cells or new statements before or after the line of code containing the **???**.
# * Since you'll be using a temporary online service for code execution, save your work by running `jovian.commit` at regular intervals.
# * Questions marked **(Optional)** will not be considered for evaluation, and can be skipped. They are for your learning.
#
# You can make submissions on this page: https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas/assignment/assignment-3-pandas-practice
#
# If you are stuck, you can ask for help on the community forum: https://jovian.ml/forum/t/assignment-3-pandas-practice/11225/3 . You can get help with errors or ask for hints, describe your approach in simple words, link to documentation, but **please don't ask for or share the full working answer code** on the forum.
#
#
# ## How to run the code and save your work
#
# The recommended way to run this notebook is to click the "Run" button at the top of this page, and select "Run on Binder". This will run the notebook on [mybinder.org](https://mybinder.org), a free online service for running Jupyter notebooks.
#
# Before staring the assignment, let's save a snapshot of the assignment to your Jovian.ml profile, so that you can access it later, and continue your work.

# %%
# Run the next line to install Pandas
# !pip install pandas --upgrade

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# In this assignment, we're going to analyze an operate on data from a CSV file. Let's begin by downloading the CSV file.

# %%
from urllib.request import urlretrieve
# from urllib.request import urlretrieve

urlretrieve('https://hub.jovian.ml/wp-content/uploads/2020/09/countries.csv', 
            'countries.csv')
# Out:
# ('countries.csv', <http.client.HTTPMessage at 0x25ffc6cc5b0>)

# %% [markdown]
# Let's load the data from the CSV file into a Pandas data frame.

# %%
countries_df = pd.read_csv('countries.csv')

# %%
countries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   location                    210 non-null    object
#  1   continent                   210 non-null    object
#  2   population                  210 non-null    float64
#  3   life_expectancy             207 non-null    float64
#  4   hospital_beds_per_thousand  164 non-null    float64
#  5   gdp_per_capita              183 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 10.0+ KB

# %%
countries_df.describe()
# Out:
#          population  life_expectancy  hospital_beds_per_thousand  \
# count  2.100000e+02       207.000000                  164.000000
# mean   3.694276e+07        73.529855                    3.012671
# std    1.425092e+08         7.560056                    2.464917
# min    8.090000e+02        53.280000                    0.100000
# 25%    1.031042e+06        69.260000                    1.300000
# 50%    6.909866e+06        75.090000                    2.358500
# 75%    2.615868e+07        78.940000                    3.895750
# max    1.439324e+09        86.750000                   13.800000
#
#        gdp_per_capita
# count      183.000000
# mean     19485.912399
# std      19820.802488
# min        661.240000
# 25%       4504.151000
# 50%      13111.214000
# 75%      28349.983500
# max     116935.600000

# %%
countries_df.head()
# Out:
#       location continent  population  life_expectancy  \
# 0  Afghanistan      Asia  38928341.0            64.83
# 1      Albania    Europe   2877800.0            78.57
# 2      Algeria    Africa  43851043.0            76.88
# 3      Andorra    Europe     77265.0            83.73
# 4       Angola    Africa  32866268.0            61.15
#
#    hospital_beds_per_thousand  gdp_per_capita
# 0                        0.50        1803.987
# 1                        2.89       11803.431
# 2                        1.90       13913.839
# 3                         NaN             NaN
# 4                         NaN        5819.495

# %%
bool_gdp_nan = pd.isnull(countries_df['gdp_per_capita'])

# %%
countries_df[bool_gdp_nan].shape
# Out:
# (27, 6)

# %% [markdown]
# **Q1: How many countries does the dataframe contain?**
#
# Hint: Use the `.shape` method.

# %%
num_countries = countries_df.shape[0]

# %%
print('There are {} countries in the dataset'.format(num_countries))
# Out:
# There are 210 countries in the dataset

# %%
# jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# **Q2: Retrieve a list of continents from the dataframe?**
#
# *Hint: Use the `.unique` method of a series.*

# %%
countries_df.head()
# Out:
#       location continent  population  life_expectancy  \
# 0  Afghanistan      Asia  38928341.0            64.83
# 1      Albania    Europe   2877800.0            78.57
# 2      Algeria    Africa  43851043.0            76.88
# 3      Andorra    Europe     77265.0            83.73
# 4       Angola    Africa  32866268.0            61.15
#
#    hospital_beds_per_thousand  gdp_per_capita
# 0                        0.50        1803.987
# 1                        2.89       11803.431
# 2                        1.90       13913.839
# 3                         NaN             NaN
# 4                         NaN        5819.495

# %%
continents = countries_df.continent.unique()

# %%
continents
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
len(continents)
# Out:
# 6

# %%
# jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# **Q3: What is the total population of all the countries listed in this dataset?**

# %%
countries_df.info() # No Null Values in the Population column, so we can continue with the calculation withour worrying about the NAN values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   location                    210 non-null    object
#  1   continent                   210 non-null    object
#  2   population                  210 non-null    float64
#  3   life_expectancy             207 non-null    float64
#  4   hospital_beds_per_thousand  164 non-null    float64
#  5   gdp_per_capita              183 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 10.0+ KB

# %%
total_population = countries_df[['population']].sum()

# %%
print('The total population is {}.'.format(int(total_population)))
# Out:
# The total population is 7757980095.

# %%
# jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# **Q: (Optional) What is the overall life expectancy across in the world?**
#
# *Hint: You'll need to take a weighted average of life expectancy using populations as weights.*

# %%
countries_df.info() ##Only 3 nan in life_expectancy, it will not affect the calculations assuch.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   location                    210 non-null    object
#  1   continent                   210 non-null    object
#  2   population                  210 non-null    float64
#  3   life_expectancy             207 non-null    float64
#  4   hospital_beds_per_thousand  164 non-null    float64
#  5   gdp_per_capita              183 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 10.0+ KB

# %%
over_all_expectancy = ((countries_df.population*countries_df.life_expectancy).sum())/(countries_df.population.sum())

# %%
over_all_expectancy
# Out:
# 72.72165193409664

# %%
# jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# **Q4: Create a dataframe containing 10 countries with the highest population.**
#
# *Hint: Chain the `sort_values` and `head` methods.*

# %%
countries_df.sort_values(by = 'population', ascending=False).head(10)
# Out:
#           location      continent    population  life_expectancy  \
# 41           China           Asia  1.439324e+09            76.91
# 90           India           Asia  1.380004e+09            69.66
# 199  United States  North America  3.310026e+08            78.86
# 91       Indonesia           Asia  2.735236e+08            71.72
# 145       Pakistan           Asia  2.208923e+08            67.27
# 27          Brazil  South America  2.125594e+08            75.88
# 141        Nigeria         Africa  2.061396e+08            54.69
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 157         Russia         Europe  1.459345e+08            72.58
# 125         Mexico  North America  1.289328e+08            75.05
#
#      hospital_beds_per_thousand  gdp_per_capita
# 41                         4.34       15308.712
# 90                         0.53        6426.674
# 199                        2.77       54225.446
# 91                         1.04       11188.744
# ...

# %%
most_populous_df =countries_df.sort_values(by = 'population', ascending=False).head(10)

# %%
most_populous_df
# Out:
#           location      continent    population  life_expectancy  \
# 41           China           Asia  1.439324e+09            76.91
# 90           India           Asia  1.380004e+09            69.66
# 199  United States  North America  3.310026e+08            78.86
# 91       Indonesia           Asia  2.735236e+08            71.72
# 145       Pakistan           Asia  2.208923e+08            67.27
# 27          Brazil  South America  2.125594e+08            75.88
# 141        Nigeria         Africa  2.061396e+08            54.69
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 157         Russia         Europe  1.459345e+08            72.58
# 125         Mexico  North America  1.289328e+08            75.05
#
#      hospital_beds_per_thousand  gdp_per_capita
# 41                         4.34       15308.712
# 90                         0.53        6426.674
# 199                        2.77       54225.446
# 91                         1.04       11188.744
# ...

# %%
ax = most_populous_df.plot('gdp_per_capita','hospital_beds_per_thousand', kind = 'scatter',label ="Gdp vs Beds" ,color= "red")
most_populous_df.plot('life_expectancy','hospital_beds_per_thousand', xlabel = 'life expectancy', ylabel='hospital beds per thousand', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='life expectancy', ylabel='hospital beds per thousand'>

# %%
# jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# **Q5: Add a new column in `countries_df` to record the overall GDP per country (product of population & per capita GDP).**

# %%
countries_df.head()
# Out:
#       location continent  population  life_expectancy  \
# 0  Afghanistan      Asia  38928341.0            64.83
# 1      Albania    Europe   2877800.0            78.57
# 2      Algeria    Africa  43851043.0            76.88
# 3      Andorra    Europe     77265.0            83.73
# 4       Angola    Africa  32866268.0            61.15
#
#    hospital_beds_per_thousand  gdp_per_capita
# 0                        0.50        1803.987
# 1                        2.89       11803.431
# 2                        1.90       13913.839
# 3                         NaN             NaN
# 4                         NaN        5819.495

# %%
countries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   location                    210 non-null    object
#  1   continent                   210 non-null    object
#  2   population                  210 non-null    float64
#  3   life_expectancy             207 non-null    float64
#  4   hospital_beds_per_thousand  164 non-null    float64
#  5   gdp_per_capita              183 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 10.0+ KB

# %%
#Doesnt Work#Filling NAN values in the gdp_per_capita column with the mean values of a continent to better account for the economic development

# %%
countries_df.gdp_per_capita.mean()
# Out:
# 19485.912398907098

# %%
bool= countries_df.gdp_per_capita.isnull()

# %%
countries_df.loc[bool , 'gdp_per_capita'] = 19631.562790989185

# %%
countries_df['GDP per country'] = countries_df.population*countries_df.gdp_per_capita

# %%
# jovian.commit(project='pandas-practice-assignment', environment=None)

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  GDP per country
# 0                          0.50     1803.987000     7.022622e+10
# 1                          2.89    11803.431000     3.396791e+10
# ...

# %% [markdown]
# **Q: (Optional) Create a dataframe containing 10 countries with the lowest GDP per capita, among the counties with population greater than 100 million.**

# %%
countries_df[countries_df.population > 100000000].sort_values('gdp_per_capita', ascending=False).tail(14)
# Out:
#           location      continent    population  life_expectancy  \
# 199  United States  North America  3.310026e+08            78.86
# 99           Japan           Asia  1.264765e+08            84.63
# 157         Russia         Europe  1.459345e+08            72.58
# 125         Mexico  North America  1.289328e+08            75.05
# 41           China           Asia  1.439324e+09            76.91
# 27          Brazil  South America  2.125594e+08            75.88
# 91       Indonesia           Asia  2.735236e+08            71.72
# 58           Egypt         Africa  1.023344e+08            71.99
# 151    Philippines           Asia  1.095811e+08            71.23
# 90           India           Asia  1.380004e+09            69.66
# 141        Nigeria         Africa  2.061396e+08            54.69
# 145       Pakistan           Asia  2.208923e+08            67.27
# 15      Bangladesh           Asia  1.646894e+08            72.59
# ...

# %%
bottom_10_gdp_per_capita_df = countries_df[countries_df.population > 100000000].sort_values('gdp_per_capita', ascending=False).tail(10).copy()

# %%
bottom_10_gdp_per_capita_df
# Out:
#         location      continent    population  life_expectancy  \
# 41         China           Asia  1.439324e+09            76.91
# 27        Brazil  South America  2.125594e+08            75.88
# 91     Indonesia           Asia  2.735236e+08            71.72
# 58         Egypt         Africa  1.023344e+08            71.99
# 151  Philippines           Asia  1.095811e+08            71.23
# 90         India           Asia  1.380004e+09            69.66
# 141      Nigeria         Africa  2.061396e+08            54.69
# 145     Pakistan           Asia  2.208923e+08            67.27
# 15    Bangladesh           Asia  1.646894e+08            72.59
# 63      Ethiopia         Africa  1.149636e+08            66.60
#
#      hospital_beds_per_thousand  gdp_per_capita  GDP per country
# 41                         4.34       15308.712     2.203419e+13
# 27                         2.20       14103.452     2.997821e+12
# 91                         1.04       11188.744     3.060386e+12
# ...

# %%
jovian.commit(project='pandas-practice-assignment', environment=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-2dfee9f9db90> in <module>
# ----> 1 jovian.commit(project='pandas-practice-assignment', environment=None)
#
# NameError: name 'jovian' is not defined

# %% [markdown]
# **Q6: Create a data frame that counts the number countries in each continent?**
#
# *Hint: Use `groupby`, select the `location` column and aggregate using `count`.*

# %%
country_counts_df = pd.DataFrame()

# %%
country_counts_df = pd.DataFrame(countries_df.groupby('continent')['location'].count().copy())

# %%
type(country_counts_df)
# Out:
# pandas.core.frame.DataFrame

# %%
country_counts_df.rename(columns={'location' : 'number_of_countries'}, inplace=True )

# %%
country_counts_df
# Out:
#                number_of_countries
# continent
# Africa                          55
# Asia                            47
# Europe                          51
# North America                   36
# Oceania                          8
# South America                   13

# %%
jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# **Q7: Create a data frame showing the total population of each continent.**
#
# *Hint: Use `groupby`, select the population column and aggregate using `sum`.*

# %%
continent_populations_df = pd.DataFrame(countries_df.groupby('continent').population.sum())

# %%
continent_populations_df
# Out:
#                  population
# continent
# Africa         1.339424e+09
# Asia           4.607388e+09
# Europe         7.485062e+08
# North America  5.912425e+08
# Oceania        4.095832e+07
# South America  4.304611e+08

# %%
# jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# Let's download another CSV file containing overall Covid-19 stats for various countires, and read the data into another Pandas data frame.

# %%
urlretrieve('https://hub.jovian.ml/wp-content/uploads/2020/09/covid-countries-data.csv', 
            'covid-countries-data.csv')
# Out:
# ('covid-countries-data.csv', <http.client.HTTPMessage at 0x25ffe98ef70>)

# %%
covid_data_df = pd.read_csv('covid-countries-data.csv')

# %%
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %% [markdown]
# **Q8: Count the number of countries for which the `total_tests` data is missing.**
#
# *Hint: Use the `.isna` method.*

# %%
covid_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   location      212 non-null    object
#  1   total_cases   211 non-null    float64
#  2   total_deaths  211 non-null    float64
#  3   total_tests   90 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 6.8+ KB

# %%
total_tests_missing = len(covid_data_df.total_tests[covid_data_df.total_tests.isna()])

# %%
print("The data for total tests is missing for {} countries.".format(int(total_tests_missing)))
# Out:
# The data for total tests is missing for 122 countries.

# %%
# jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# Let's merge the two data frames, and compute some more metrics.
#
# **Q9: Merge `countries_df` with `covid_data_df` on the `location` column.**
#
# *Hint: Use the `.merge` method on `countries_df`.

# %%
combined_df = pd.merge(countries_df, covid_data_df, on = 'location')

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  GDP per country  total_cases  \
# 0                          0.50     1803.987000     7.022622e+10      38243.0
# 1                          2.89    11803.431000     3.396791e+10       9728.0
# ...

# %%
# jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# **Q10: Add columns `tests_per_million`, `cases_per_million` and `deaths_per_million` into `combined_df`.**

# %%
combined_df[['population','total_cases', 'total_deaths', 'total_tests']]
# Out:
#      population  total_cases  total_deaths  total_tests
# 0    38928341.0      38243.0        1409.0          NaN
# 1     2877800.0       9728.0         296.0          NaN
# 2    43851043.0      45158.0        1525.0          NaN
# 3       77265.0       1199.0          53.0          NaN
# 4    32866268.0       2729.0         109.0          NaN
# ..          ...          ...           ...          ...
# 205  97338583.0       1046.0          35.0     261004.0
# 206    597330.0        766.0           1.0          NaN
# 207  29825968.0       1976.0         571.0          NaN
# 208  18383956.0      12415.0         292.0          NaN
# 209  14862927.0       6638.0         206.0      97272.0
#
# [210 rows x 4 columns]

# %%
combined_df['tests_per_million'] = combined_df['total_tests'] * 1e6 / combined_df['population']

# %%
combined_df['cases_per_million'] = combined_df['total_cases'] * 1e6 / combined_df['population']

# %%
combined_df['deaths_per_million'] = combined_df['total_deaths'] * 1e6 / combined_df['population']

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  GDP per country  total_cases  \
# 0                          0.50     1803.987000     7.022622e+10      38243.0
# 1                          2.89    11803.431000     3.396791e+10       9728.0
# ...

# %%
# jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# **Q11: Create a dataframe with 10 countires that have highest number of tests per million people.**

# %%
highest_tests_df = pd.DataFrame(combined_df.sort_values('tests_per_million', ascending=False).head(10))

# %%
highest_tests_df
# Out:
#                  location      continent   population  life_expectancy  \
# 197  United Arab Emirates           Asia    9890400.0            77.97
# 14                Bahrain           Asia    1701583.0            77.29
# 115            Luxembourg         Europe     625976.0            82.25
# 122                 Malta         Europe     441539.0            82.53
# 53                Denmark         Europe    5792203.0            80.90
# 96                 Israel           Asia    8655541.0            82.97
# 89                Iceland         Europe     341250.0            82.99
# 157                Russia         Europe  145934460.0            72.58
# 199         United States  North America  331002647.0            78.86
# 10              Australia        Oceania   25499881.0            83.44
#
#      hospital_beds_per_thousand  gdp_per_capita  GDP per country  total_cases  \
# 197                       1.200       67293.483     6.655595e+11      71540.0
# ...

# %%
# jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# **Q12: Create a dataframe with 10 countires that have highest number of positive cases per million people.**

# %%
highest_cases_df =  pd.DataFrame(combined_df.sort_values('cases_per_million', ascending=False).head(10))

# %%
highest_cases_df
# Out:
#           location      continent   population  life_expectancy  \
# 155          Qatar           Asia    2881060.0            80.23
# 14         Bahrain           Asia    1701583.0            77.29
# 147         Panama  North America    4314768.0            78.51
# 40           Chile  South America   19116209.0            80.18
# 162     San Marino         Europe      33938.0            84.97
# 9            Aruba  North America     106766.0            76.29
# 105         Kuwait           Asia    4270563.0            75.49
# 150           Peru  South America   32971846.0            76.74
# 27          Brazil  South America  212559409.0            75.88
# 199  United States  North America  331002647.0            78.86
#
#      hospital_beds_per_thousand  gdp_per_capita  GDP per country  total_cases  \
# 155                        1.20      116935.600     3.368985e+11     119206.0
# 14                         2.00       43290.705     7.366273e+10      52440.0
# ...

# %%
# jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# **Q13: Create a dataframe with 10 countires that have highest number of deaths cases per million people?**

# %%
highest_deaths_df = pd.DataFrame(combined_df.sort_values('deaths_per_million', ascending=False).head(10))

# %%
highest_deaths_df
# Out:
#            location      continent   population  life_expectancy  \
# 162      San Marino         Europe      33938.0            84.97
# 150            Peru  South America   32971846.0            76.74
# 18          Belgium         Europe   11589616.0            81.63
# 3           Andorra         Europe      77265.0            83.73
# 177           Spain         Europe   46754783.0            83.56
# 198  United Kingdom         Europe   67886004.0            81.32
# 40            Chile  South America   19116209.0            80.18
# 97            Italy         Europe   60461828.0            83.51
# 27           Brazil  South America  212559409.0            75.88
# 182          Sweden         Europe   10099270.0            82.80
#
#      hospital_beds_per_thousand  gdp_per_capita  GDP per country  total_cases  \
# 162                        3.80    56861.470000     1.929765e+09        735.0
# 150                        1.60    12236.706000     4.034668e+11     663437.0
# ...

# %%
jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# **(Optional) Q: Count number of countries that feature in both the lists of "highest number of tests per million" and "highest number of cases per million".**

# %%
highest_deaths_df.set_index('location')
# Out:
#                     continent   population  life_expectancy  \
# location
# San Marino             Europe      33938.0            84.97
# Peru            South America   32971846.0            76.74
# Belgium                Europe   11589616.0            81.63
# Andorra                Europe      77265.0            83.73
# Spain                  Europe   46754783.0            83.56
# United Kingdom         Europe   67886004.0            81.32
# Chile           South America   19116209.0            80.18
# Italy                  Europe   60461828.0            83.51
# Brazil          South America  212559409.0            75.88
# Sweden                 Europe   10099270.0            82.80
#
#                 hospital_beds_per_thousand  gdp_per_capita  GDP per country  \
# location
# San Marino                            3.80    56861.470000     1.929765e+09
# Peru                                  1.60    12236.706000     4.034668e+11
# ...

# %%
highest_cases_df.set_index('location')
# Out:
#                    continent   population  life_expectancy  \
# location
# Qatar                   Asia    2881060.0            80.23
# Bahrain                 Asia    1701583.0            77.29
# Panama         North America    4314768.0            78.51
# Chile          South America   19116209.0            80.18
# San Marino            Europe      33938.0            84.97
# Aruba          North America     106766.0            76.29
# Kuwait                  Asia    4270563.0            75.49
# Peru           South America   32971846.0            76.74
# Brazil         South America  212559409.0            75.88
# United States  North America  331002647.0            78.86
#
#                hospital_beds_per_thousand  gdp_per_capita  GDP per country  \
# location
# Qatar                                1.20      116935.600     3.368985e+11
# Bahrain                              2.00       43290.705     7.366273e+10
# ...

# %%
common_highest_cases_deaths_df = pd.merge(highest_cases_df,highest_deaths_df)

# %%
common_highest_cases_deaths_df
# Out:
#      location      continent   population  life_expectancy  \
# 0       Chile  South America   19116209.0            80.18
# 1  San Marino         Europe      33938.0            84.97
# 2        Peru  South America   32971846.0            76.74
# 3      Brazil  South America  212559409.0            75.88
#
#    hospital_beds_per_thousand  gdp_per_capita  GDP per country  total_cases  \
# 0                        2.11       22767.037     4.352194e+11     414739.0
# 1                        3.80       56861.470     1.929765e+09        735.0
# 2                        1.60       12236.706     4.034668e+11     663437.0
# 3                        2.20       14103.452     2.997821e+12    3997865.0
#
#    total_deaths  total_tests  tests_per_million  cases_per_million  \
# 0       11344.0    2458762.0      128621.841287       21695.671982
# 1          42.0          NaN                NaN       21657.139490
# 2       29259.0     584232.0       17719.117092       20121.318048
# ...

# %%
jovian.commit(project='pandas-practice-assignment', environment=None)?

# %% [markdown]
# **(Optional) Q: Count number of countries that feature in both the lists "20 countries with lowest GDP per capita" and "20 countries with the lowest number of hospital beds per thousand population". Only consider countries with a population higher than 10 million while creating the list.**

# %%
countries_df.population>1
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  GDP per country
# 0                          0.50     1803.987000     7.022622e+10
# 1                          2.89    11803.431000     3.396791e+10
# ...

# %%
low_20_gdp_df = pd.DataFrame(countries_df[countries_df.population>10000000].sort_values('gdp_per_capita', ascending=True).head(20))

# %%
low_20_bed_df = pd.DataFrame(countries_df[countries_df.population>10000000].sort_values('hospital_beds_per_thousand', ascending=True).head(20))

# %%
df = low_20_gdp_df.merge(low_20_bed_df, on='location', suffixes=(" "," "))

# %%
df = df.loc[:,~df.columns.duplicated()]

# %%
df
# Out:
#         location     continent   population   life_expectancy   \
# 0        Burundi         Africa   11890781.0             61.58
# 1          Niger         Africa   24206636.0             62.42
# 2     Mozambique         Africa   31255435.0             60.85
# 3     Madagascar         Africa   27691019.0             67.04
# 4          Yemen           Asia   29825968.0             66.12
# 5          Haiti  North America   11402533.0             64.00
# 6         Uganda         Africa   45741000.0             63.37
# 7   Burkina Faso         Africa   20903278.0             61.58
# 8       Ethiopia         Africa  114963583.0             66.60
# 9    Afghanistan           Asia   38928341.0             64.83
# 10        Guinea         Africa   13132792.0             61.60
# 11          Mali         Africa   20250834.0             59.31
# 12         Benin         Africa   12123198.0             61.77
# 13         Nepal           Asia   29136808.0             70.78
#
# ...

# %%
jovian.commit(project='pandas-practice-assignment', environment=None)

# %% [markdown]
# ## Submission
#
# Congratulations on making it this far! You've reached the end of this assignment, and you just completed your first real-world data analysis problem. It's time to record one final version of your notebook for submission.
#
# Make a submission here by filling the submission form: https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas/assignment/assignment-3-pandas-practice
#
# Also make sure to help others on the forum: https://jovian.ml/forum/t/assignment-3-pandas-practice/11225/2

# %%
import sklearn

# %%
combined_df.columns
# Out:
# Index(['location', 'continent', 'population', 'life_expectancy',
#        'hospital_beds_per_thousand', 'gdp_per_capita', 'GDP per country',
#        'total_cases', 'total_deaths', 'total_tests', 'tests_per_million',
#        'cases_per_million', 'deaths_per_million'],
#       dtype='object')

# %%
x = combined_df[['location','population', 'life_expectancy','hospital_beds_per_thousand','gdp_per_capita',
       'total_cases', 'total_tests']]

# %%
y= combined_df['total_deaths']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x ,y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
